# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import warnings
import zipfile
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
# from ydata_profiling import ProfileReport
import dtale

# %%
# Define the path to the ZIP file
zip_path = r'C:\Users\nadav\Downloads\child-mind-institute-problematic-internet-use.zip'

# %%
# Open the ZIP file and read the CSV files inside
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract the names of train, test, and sample_submission files
    train_file = 'train.csv'
    test_file = 'test.csv'
    data_dictionary = 'data_dictionary.csv'

    
    # Read the CSV files into pandas DataFrames
    with zip_ref.open(train_file) as train, zip_ref.open(test_file) as test, zip_ref.open(data_dictionary) as data_dictionary:
        train = pd.read_csv(train, encoding='ISO-8859-1', delimiter=',', engine='python', on_bad_lines='skip')
        test = pd.read_csv(test, encoding='ISO-8859-1', delimiter=',', engine='python', on_bad_lines='skip')
        data_dictionary = pd.read_csv(data_dictionary, encoding='ISO-8859-1', delimiter=',', engine='python', on_bad_lines='skip')

# %%
train
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 3     00115b9f                    Winter                9                0
# 4     0016bb22                    Spring               18                1
# ...        ...                       ...              ...              ...
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3957  ffcd4dbd                      Fall               11                0
# 3958  ffed1dd5                    Spring               13                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# ...

# %%
test
# Out:
#           id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0   00008ff9                      Fall                5                0
# 1   000fd460                    Summer                9                0
# 2   00105258                    Summer               10                1
# 3   00115b9f                    Winter                9                0
# 4   0016bb22                    Spring               18                1
# 5   001f3379                    Spring               13                1
# 6   0038ba98                      Fall               10                0
# 7   0068a485                      Fall               10                1
# 8   0069fbed                    Summer               15                0
# 9   0083e397                    Summer               19                1
# 10  0087dd65                    Spring               11                1
# 11  00abe655                      Fall               11                0
# ...

# %%
data_dictionary
# Out:
#                             Instrument  \
# 0                           Identifier
# 1                         Demographics
# 2                         Demographics
# 3                         Demographics
# 4   Children's Global Assessment Scale
# ..                                 ...
# 76             Sleep Disturbance Scale
# 77             Sleep Disturbance Scale
# 78             Sleep Disturbance Scale
# 79                        Internet Use
# 80                        Internet Use
#
#                                      Field                       Description  \
# 0                                       id                  Participant's ID
# 1                Basic_Demos-Enroll_Season              Season of enrollment
# 2                          Basic_Demos-Age                Age of participant
# 3                          Basic_Demos-Sex                Sex of participant
# 4                              CGAS-Season           Season of participation
# ...

# %%
columns_in_train_not_in_test = set(train.columns) - set(test.columns)

# Print the columns
print("Columns in train but not in test:")
print(columns_in_train_not_in_test)
# Out:
# Columns in train but not in test:
# {'PCIAT-PCIAT_20', 'PCIAT-PCIAT_02', 'PCIAT-PCIAT_09', 'PCIAT-PCIAT_11', 'PCIAT-Season', 'PCIAT-PCIAT_17', 'PCIAT-PCIAT_Total', 'PCIAT-PCIAT_04', 'PCIAT-PCIAT_16', 'PCIAT-PCIAT_19', 'PCIAT-PCIAT_10', 'PCIAT-PCIAT_05', 'PCIAT-PCIAT_03', 'PCIAT-PCIAT_18', 'PCIAT-PCIAT_07', 'PCIAT-PCIAT_15', 'PCIAT-PCIAT_08', 'PCIAT-PCIAT_14', 'PCIAT-PCIAT_06', 'PCIAT-PCIAT_12', 'sii', 'PCIAT-PCIAT_01', 'PCIAT-PCIAT_13'}

# %%
def calculate_stats(data, columns):
    if isinstance(columns, str):
        columns = [columns]

    stats = []
    for col in columns:
        if data[col].dtype in ['object', 'category']:
            counts = data[col].value_counts(dropna=False, sort=False)
            percents = data[col].value_counts(normalize=True, dropna=False, sort=False) * 100
            formatted = counts.astype(str) + ' (' + percents.round(2).astype(str) + '%)'
            stats_col = pd.DataFrame({'count (%)': formatted})
            stats.append(stats_col)
        else:
            stats_col = data[col].describe().to_frame().transpose()
            stats_col['missing'] = data[col].isnull().sum()
            stats_col.index.name = col
            stats.append(stats_col)

    return pd.concat(stats, axis=0)

# %%
df = train.isna().sum()

# %%
df
# Out:
# id                                           0
# Basic_Demos-Enroll_Season                    0
# Basic_Demos-Age                              0
# Basic_Demos-Sex                              0
# CGAS-Season                               1405
#                                           ...
# SDS-SDS_Total_Raw                         1351
# SDS-SDS_Total_T                           1354
# PreInt_EduHx-Season                        420
# PreInt_EduHx-computerinternet_hoursday     659
# sii                                       1224
# Length: 82, dtype: int64

# %%
# Launch D-Tale for interactive analysis
d = dtale.show(train)
d.open_browser()  # Opens D-Tale in a browser for interactive exploration

# %%
# # Generate the profiling report
# profile = ProfileReport(train, title="Loan Approval Dataset EDA Report")
# 
# # Save the report as an HTML file
# profile.to_file('ydata_profiling_report.html')
# 
# profile.to_notebook_iframe()  # Display the report inline in Jupyter
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
